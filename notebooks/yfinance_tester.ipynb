# %%
import pandas as pd

# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
ticker.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
# show major holders
ticker.institutional_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0        Invesco Oppenheimer Developing Markets Fund  268141297    2020-04-30
# 1  Vanguard International Stock Index-Total Intl ...  177650867    2020-04-30
# 2  Vanguard International Stock Index-Emerging Ma...  145852442    2020-04-30
# 3             iShares Core MSCI Emerging Markets ETF   90373000    2020-04-30
# 4           Lazard Emerging Markets Equity Portfolio   53484874    2020-03-31
# 5                  iShares MSCI Emerging Markets ETF   43106741    2020-04-30
# 6  Fidelity Series Emerging Markets Opportunities...   35069950    2020-05-31
# 7             JP Morgan Emerging Markets Equity Fund   23526972    2020-05-31
# 8                     iShares MSCI Russia Capped ETF   21895880    2020-04-30
# 9  MFS Series Trust X-MFS Emerging Markets Equity...   18628597    2020-02-29
#
#     % Out        Value
# 0  0.0124  52890870833
# 1  0.0082  35041633515
# 2  0.0068  28769394184
# ...

# %%
# show institutional holders
ticker.institutional_holders
# Out:
# {}

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
stock.major_holders

# show institutional holders
stock.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2e5be7d6301e> in <module>
#       4
#       5 # get stock info
# ----> 6 msft.info
#       7
#       8 # get historical market data
#
# ~/Projects/rocket-market-core/venv/lib/python3.6/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self):
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~/Projects/rocket-market-core/venv/lib/python3.6/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     413
#     414     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 415         self._get_fundamentals(proxy)
#     416         data = self._info
#     417         if as_dict:
#
# ~/Projects/rocket-market-core/venv/lib/python3.6/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
# ...

# %%
# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')

# %%
ticker = yf.Ticker('AAPL')

# %%
hist = ticker.history(start='2020-06-30', end='2020-07-02', interval='1d', rounding=False)

# %%
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2020-06-29  353.250000  362.170013  351.279999  361.779999  32661500
# 2020-06-30  360.079987  365.980011  360.000000  364.799988  35055800
# 2020-07-01  365.119995  367.359985  363.910004  364.109985  27684300
#
#             Dividends  Stock Splits
# Date
# 2020-06-29          0             0
# 2020-06-30          0             0
# 2020-07-01          0             0

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "AAPL SBER.ME HIMC.ME GAZ.ME",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
#         period = "1d",
       start='2020-05-01', end='2020-06-03',

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = False,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = False,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = 20,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  4 of 4 completed
#
# 2 Failed downloads:
# - HIMC.ME: No data found, symbol may be delisted
# - GAZ.ME: No data found, symbol may be delisted

# %%
df['GAZ.ME']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Projects/rocket-market-core/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GAZ.ME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-969fad1a5116> in <module>
# ----> 1 df['GAZ.ME']
# ...

# %%
df = data['SBER.ME'].reset_index()
df[~df.Close.isna()]
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 2  2020-05-04  195.679993  195.679993  193.259995  193.690002  159.120300
# 3  2020-05-05  195.509995  196.460007  194.000000  194.750000  159.991119
# 4  2020-05-06  195.000000  197.229996  194.300003  195.699997  160.771545
# 5  2020-05-07  196.000000  198.149994  195.059998  195.509995  160.615463
# 6  2020-05-08  196.000000  196.250000  194.600006  196.020004  161.034454
# 8  2020-05-12  193.300003  195.919998  191.199997  191.399994  157.239014
# 9  2020-05-13  190.050003  190.600006  186.660004  187.309998  170.541046
# 10 2020-05-14  186.500000  188.199997  183.500000  183.809998  167.354385
# 11 2020-05-15  186.130005  186.779999  183.330002  183.850006  167.390808
# 12 2020-05-18  186.330002  190.000000  185.399994  188.929993  172.016022
# 13 2020-05-19  190.369995  192.550003  186.800003  189.000000  172.079758
# 14 2020-05-20  188.490005  193.979996  186.600006  193.979996  176.613922
# ...

# %%
df = data['AAPL'].reset_index()
df
# Out:
#         Date    Open        High         Low       Close    Volume
# 0 2020-06-01  317.75  322.350006  317.209991  321.850006  20197800
# 1 2020-06-02  320.75  323.440002  318.929993  323.339996  21910700

# %%
df['ticker'] = 'AAPL'
df['frequency'] = '1d'
df['source'] = 'yfinance'
df['type'] = 'history'

# %%
data['SBER.ME']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-01  203.100006  205.929993  201.809998  203.660004  185.427322
# 2020-06-02  204.669998  212.000000  204.020004  212.000000  193.020676
#
#                Volume
# Date
# 2020-06-01   65650670
# 2020-06-02  116868310

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'ticker',
#        'frequency', 'source', 'type'],
#       dtype='object')

# %%
columns_mapping = {'Date': 'ts', 'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'}

# %%
df.rename(columns=columns_mapping, inplace=)
# Out:
#           ts    open        high         low       close   Adj Close  \
# 0 2020-06-01  317.75  322.350006  317.209991  321.850006  321.850006
# 1 2020-06-02  320.75  323.440002  318.929993  323.339996  323.339996
#
#      volume ticker frequency    source     type
# 0  20197800   AAPL        1d  yfinance  history
# 1  21910700   AAPL        1d  yfinance  history

# %%
import pandahouse as ph

# %%
connection = {'host': 'http://rocket:8123',
              'database': 'rocket', 'user': 'default', 'password': 'TJtcPQem'}
df = ph.read_clickhouse('SELECT toInt32(1) as id FROM {db}.events', index_col='id',
                        connection=connection)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
